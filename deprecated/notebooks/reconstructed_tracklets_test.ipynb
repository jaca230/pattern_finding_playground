# %% [markdown]
# # Import Librarys and Files

# %% [markdown]
# ## Imports

# %% [markdown]
# ### Add top level to the import path

# %%
import sys
import os

# Add the project root to sys.path
project_root = os.path.abspath("../..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %% [markdown]
# ### Import some classes/modules we'll be using

# %%
import ROOT as r
import matplotlib.pyplot as plt
import numpy as np
from importlib import reload
from tqdm.notebook import tqdm 

import deprecated.utils.utils as utils
import deprecated.utils.plotting_utils as plotting_utils
from deprecated.models.event_patterns import EventPatterns
from models.pattern import Pattern
from models.vertex import Vertex
from models.tracklet import Tracklet
from models.hit import Hit

# %% [markdown]
# ## Load Shared libraries to access methods of ROOT objects in python

# %%
PI_ROOT_DICT_PATH = "/home/jack/large_projects/simulation/install/lib/libPiRootDict.so" #Change to match system path
r.gSystem.Load(PI_ROOT_DICT_PATH)
# Out:
# 0

# %% [markdown]
# ## Load Pattern finding truth data
# This also contains what we need to reconstruct patterns. So it gives validation (true patterns) and a method to create our own pattern

# %%
rec_file_path = "/home/jack/large_projects/simulation/workspace/playground/reco_algorithm_tests/data/all_rec_pienu_algor_05_07_25.root"
truth_rec_file_path = "/home/jack/large_projects/simulation/workspace/playground/reco_algorithm_tests/data/all_rec_pienu_truth_05_07_25.root"

# Print creation times
utils.print_file_creation_time(rec_file_path)
utils.print_file_creation_time(truth_rec_file_path)

# Open the files
rec_file = r.TFile(rec_file_path, "READ")
truth_rec_file = r.TFile(truth_rec_file_path, "READ")
# Out:
# The file '/home/jack/large_projects/simulation/workspace/playground/reco_algorithm_tests/data/all_rec_pienu_algor_05_07_25.root' was created on: 2025-05-07 19:28:58
# The file '/home/jack/large_projects/simulation/workspace/playground/reco_algorithm_tests/data/all_rec_pienu_truth_05_07_25.root' was created on: 2025-05-07 19:28:12

# %% [markdown]
# ## Get ROOT objects from our file
# Making these more than once can cause memory leaks

# %%
tree = rec_file.Get("rec")
truth_tree = truth_rec_file.Get("rec")
geoHelper = rec_file.Get("GeoHeader")

# %% [markdown]
# ## (Optional) Validate the file

# %%
print(f"Entries: {tree.GetEntries()}")

tree.GetEntry(0)  # Load the first entry

vec_names = [branch.GetName() for branch in tree.GetListOfBranches()]
print("Branches:")
print(vec_names)

for name in vec_names:
    vec = getattr(tree, name)
    print(f"\n{name} (size = {len(vec)}):")
    for i, item in enumerate(vec):
        print(f"  [{i}] {item}")
# Out:
# Entries: 5876
# Branches:
# ['infoVec', 'dtarHitsVec', 'atarHitsVec', 'trackerHitsVec', 'caloHitsVec', 'tagVec', 'summaryVec', 'patternVec', 'trackletVec', 'clusterVec']
#
# infoVec (size = 1):
#   [0] Name: PIMCInfo Title:
#
# dtarHitsVec (size = 1):
#   [0] Name: PIRECTrackletHit Title:
#
# atarHitsVec (size = 57):
#   [0] Name: PIRECTrackletHit Title:
#   [1] Name: PIRECTrackletHit Title:
#   [2] Name: PIRECTrackletHit Title:
#   [3] Name: PIRECTrackletHit Title:
#   [4] Name: PIRECTrackletHit Title:
#   [5] Name: PIRECTrackletHit Title:
#   [6] Name: PIRECTrackletHit Title:
#   [7] Name: PIRECTrackletHit Title:
#   [8] Name: PIRECTrackletHit Title:
#   [9] Name: PIRECTrackletHit Title:
#   [10] Name: PIRECTrackletHit Title:
#   [11] Name: PIRECTrackletHit Title:
#   [12] Name: PIRECTrackletHit Title:
#   [13] Name: PIRECTrackletHit Title:
#   [14] Name: PIRECTrackletHit Title:
#   [15] Name: PIRECTrackletHit Title:
#   [16] Name: PIRECTrackletHit Title:
#   [17] Name: PIRECTrackletHit Title:
#   [18] Name: PIRECTrackletHit Title:
#   [19] Name: PIRECTrackletHit Title:
#   [20] Name: PIRECTrackletHit Title:
#   [21] Name: PIRECTrackletHit Title:
#   [22] Name: PIRECTrackletHit Title:
#   [23] Name: PIRECTrackletHit Title:
#   [24] Name: PIRECTrackletHit Title:
#   [25] Name: PIRECTrackletHit Title:
#   [26] Name: PIRECTrackletHit Title:
#   [27] Name: PIRECTrackletHit Title:
#   [28] Name: PIRECTrackletHit Title:
#   [29] Name: PIRECTrackletHit Title:
#   [30] Name: PIRECTrackletHit Title:
#   [31] Name: PIRECTrackletHit Title:
#   [32] Name: PIRECTrackletHit Title:
#   [33] Name: PIRECTrackletHit Title:
#   [34] Name: PIRECTrackletHit Title:
#   [35] Name: PIRECTrackletHit Title:
#   [36] Name: PIRECTrackletHit Title:
#   [37] Name: PIRECTrackletHit Title:
#   [38] Name: PIRECTrackletHit Title:
#   [39] Name: PIRECTrackletHit Title:
#   [40] Name: PIRECTrackletHit Title:
#   [41] Name: PIRECTrackletHit Title:
#   [42] Name: PIRECTrackletHit Title:
#   [43] Name: PIRECTrackletHit Title:
#   [44] Name: PIRECTrackletHit Title:
#   [45] Name: PIRECTrackletHit Title:
#   [46] Name: PIRECTrackletHit Title:
#   [47] Name: PIRECTrackletHit Title:
#   [48] Name: PIRECTrackletHit Title:
#   [49] Name: PIRECTrackletHit Title:
#   [50] Name: PIRECTrackletHit Title:
#   [51] Name: PIRECTrackletHit Title:
#   [52] Name: PIRECTrackletHit Title:
#   [53] Name: PIRECTrackletHit Title:
#   [54] Name: PIRECTrackletHit Title:
#   [55] Name: PIRECTrackletHit Title:
#   [56] Name: PIRECTrackletHit Title:
#
# trackerHitsVec (size = 5):
#   [0] Name: PIRECTrackletHit Title:
#   [1] Name: PIRECTrackletHit Title:
#   [2] Name: PIRECTrackletHit Title:
#   [3] Name: PIRECTrackletHit Title:
#   [4] Name: PIRECTrackletHit Title:
#
# caloHitsVec (size = 5):
#   [0] Name: PIRECCaloHit Title:
#   [1] Name: PIRECCaloHit Title:
#   [2] Name: PIRECCaloHit Title:
#   [3] Name: PIRECCaloHit Title:
#   [4] Name: PIRECCaloHit Title:
#
# tagVec (size = 2):
#   [0] Name: PIMCTaggedParticle Title:
#   [1] Name: PIMCTaggedParticle Title:
#
# summaryVec (size = 1):
#   [0] Name: PIRECSummary Title:
#
# patternVec (size = 1):
#   [0] Name: PIRECAtarPattern Title:
#
# trackletVec (size = 2):
#   [0] Name: PIRECTracklet Title:
#   [1] Name: PIRECTracklet Title:
#
# clusterVec (size = 1):
#   [0] Name: PIRECCaloCluster Title:

# %% [markdown]
# # Create Python Structure from Event Data

# %% [markdown]
# ## Initialize Event Patterns Object

# %%
# Initialize Event patterns without tracklet, vertex, and pattern forming algorithms (we'll add them later)
event_index = 0
event_patterns = EventPatterns(event_index, None, None, None, validator = None)

# For "normal use" you'd just initialize with all 3 pattern forming algorithms here, then call event_patterns.form_all(file, index)
# Below, we go through each step instead:

# %% [markdown]
# ## Create tracklets for an event

# %%
# Choose a tracklet forming algorithm, I'm use this default one, but you can write your own child class of TrackletFormer
import algorithms.tracklet.reconstructed_tracklet_former
reload(algorithms.tracklet.reconstructed_tracklet_former)

from algorithms.tracklet.reconstructed_tracklet_former import ReconstructedTrackletFormer
event_patterns.tracklet_former = ReconstructedTrackletFormer(truth_tree)
event_patterns.form_tracklets(tree, geoHelper, event_index)

# Plot the tracklets
reload(plotting_utils)
plotting_utils.plot_event(event_patterns)

unique_tracklets = {
    tracklet
    for pattern in event_patterns.get_patterns()
    for vertex in pattern.get_vertices()
    for tracklet in vertex.get_tracklets()
}

print(f"Total unique tracklets: {len(unique_tracklets)}")
for i, tracklet in enumerate(unique_tracklets):
    endpoint_0, endpoint_1 = tracklet.get_endpoints()
    print(f"Tracklet {i}:")
    print(f"  Endpoint 0: {endpoint_0}")
    print(f"  Endpoint 1: {endpoint_1}")


# See the extra info stored at this point
print("Extra event info:")
print(event_patterns.extra_info)
# Out:
# Total unique tracklets: 2
# Tracklet 0:
#   Endpoint 0: Point3D(x=-3.9000000955066736, y=2.544543645250344, z=2.8890156019267415)
#   Endpoint 1: Point3D(x=-3.7000000396190598, y=6.362820158978518, z=6.700298599357359)
# Tracklet 1:
#   Endpoint 0: Point3D(x=-3.5478806753736434, y=2.2999999522858343, z=-0.2509986437801748)
#   Endpoint 1: Point3D(x=-3.900000056326043, y=2.500000000000054, z=2.987697185521827)
# Extra event info:
# {'stage': <Stage.TRACKLETS_FORMED: 1>, 'tracklet_algorithm_info': {'n_patterns_truth': 1, 'particles_in_event_truth': Counter({211: 1, -11: 1}), 'patterns_truth': {0: [0, 1]}, 'particles_in_event_reco': Counter({211: 1, -11: 1})}}

# %% [markdown]
# ## Create Vertices from Tracklets

# %%
# Choose a vertex forming algorithm, I'm using this kmeans one, but you can write your own child class of VertexFormer
from algorithms.vertex.kmeans_vertex_former_given_endpoints import KMeansVertexFormerGivenEndpoints
event_patterns.vertex_former = KMeansVertexFormerGivenEndpoints()

event_patterns.form_vertices()

reload(plotting_utils)
plotting_utils.plot_event(event_patterns)

# See the extra info stored at this point
print("Extra event info:")
print(event_patterns.extra_info)
# Out:
# Extra event info:
# {'stage': <Stage.VERTICES_FORMED: 2>, 'tracklet_algorithm_info': {'n_patterns_truth': 1, 'particles_in_event_truth': Counter({211: 1, -11: 1}), 'patterns_truth': {0: [0, 1]}, 'particles_in_event_reco': Counter({211: 1, -11: 1})}, 'vertex_algorithm_info': {'vertex_comparison': {'front_vertices': {Vertex(id=0, num_tracklets=1), Vertex(id=2, num_tracklets=2), Vertex(id=1, num_tracklets=1)}, 'back_vertices': {Vertex(id=0, num_tracklets=1), Vertex(id=1, num_tracklets=2), Vertex(id=2, num_tracklets=1)}, 'both_vertices': {Vertex(id=0, num_tracklets=1), Vertex(id=1, num_tracklets=2), Vertex(id=2, num_tracklets=1)}}, 'stats': {'front': {'BIC': 9.972601881213503, 'k': 3, 'centroids': array([[-3.54788068,  0.        , -0.25099864],
#        [-3.70000004,  0.        ,  6.7002986 ],
#        [-3.90000008,  0.        ,  2.93835639]]), 'iteration': 1, 'all_iterations': [{'bic': 36.25508050101685, 'k': 1, 'vertices': array([[-3.76197022,  0.        ,  3.08150319]]), 'iteration': 1}, {'bic': 36.25508050101685, 'k': 1, 'vertices': array([[-3.76197022,  0.        ,  3.08150319]]), 'iteration': 2}, {'bic': 36.25508050101685, 'k': 1, 'vertices': array([[-3.76197022,  0.        ,  3.08150319]]), 'iteration': 3}, {'bic': 36.25508050101685, 'k': 1, 'vertices': array([[-3.76197022,  0.        ,  3.08150319]]), 'iteration': 4}, {'bic': 36.25508050101685, 'k': 1, 'vertices': array([[-3.76197022,  0.        ,  3.08150319]]), 'iteration': 5}, {'bic': 35.70230266722402, 'k': 2, 'vertices': array([[-3.72394039,  0.        ,  1.31900848],
#        [-3.80000005,  0.        ,  4.84399789]]), 'iteration': 1}, {'bic': 35.70230266722402, 'k': 2, 'vertices': array([[-3.72394039,  0.        ,  1.31900848],
#        [-3.80000005,  0.        ,  4.84399789]]), 'iteration': 2}, {'bic': 35.70230266722402, 'k': 2, 'vertices': array([[-3.72394039,  0.        ,  1.31900848],
#        [-3.80000005,  0.        ,  4.84399789]]), 'iteration': 3}, {'bic': 35.70230266722402, 'k': 2, 'vertices': array([[-3.72394039,  0.        ,  1.31900848],
#        [-3.80000005,  0.        ,  4.84399789]]), 'iteration': 4}, {'bic': 35.70230266722402, 'k': 2, 'vertices': array([[-3.72394039,  0.        ,  1.31900848],
#        [-3.80000005,  0.        ,  4.84399789]]), 'iteration': 5}, {'bic': 9.972601881213503, 'k': 3, 'vertices': array([[-3.54788068,  0.        , -0.25099864],
#        [-3.70000004,  0.        ,  6.7002986 ],
#        [-3.90000008,  0.        ,  2.93835639]]), 'iteration': 1}, {'bic': 9.972601881213503, 'k': 3, 'vertices': array([[-3.54788068,  0.        , -0.25099864],
#        [-3.70000004,  0.        ,  6.7002986 ],
#        [-3.90000008,  0.        ,  2.93835639]]), 'iteration': 2}, {'bic': 9.972601881213503, 'k': 3, 'vertices': array([[-3.54788068,  0.        , -0.25099864],
#        [-3.70000004,  0.        ,  6.7002986 ],
#        [-3.90000008,  0.        ,  2.93835639]]), 'iteration': 3}, {'bic': 9.972601881213503, 'k': 3, 'vertices': array([[-3.54788068,  0.        , -0.25099864],
#        [-3.70000004,  0.        ,  6.7002986 ],
#        [-3.90000008,  0.        ,  2.93835639]]), 'iteration': 4}, {'bic': 9.972601881213503, 'k': 3, 'vertices': array([[-3.54788068,  0.        , -0.25099864],
#        [-3.70000004,  0.        ,  6.7002986 ],
#        [-3.90000008,  0.        ,  2.93835639]]), 'iteration': 5}]}, 'back': {'BIC': 10.010951822295409, 'k': 3, 'centroids': array([[ 0.        ,  2.29999995, -0.25099864],
#        [ 0.        ,  2.52227182,  2.93835639],
#        [ 0.        ,  6.36282016,  6.7002986 ]]), 'iteration': 2, 'all_iterations': [{'bic': 46.85525532440403, 'k': 1, 'vertices': array([[0.        , 3.42684094, 3.08150319]]), 'iteration': 1}, {'bic': 46.85525532440403, 'k': 1, 'vertices': array([[0.        , 3.42684094, 3.08150319]]), 'iteration': 2}, {'bic': 46.85525532440403, 'k': 1, 'vertices': array([[0.        , 3.42684094, 3.08150319]]), 'iteration': 3}, {'bic': 46.85525532440403, 'k': 1, 'vertices': array([[0.        , 3.42684094, 3.08150319]]), 'iteration': 4}, {'bic': 46.85525532440403, 'k': 1, 'vertices': array([[0.        , 3.42684094, 3.08150319]]), 'iteration': 5}, {'bic': 40.8307541248476, 'k': 2, 'vertices': array([[0.        , 4.33141006, 3.22464998],
#        [0.        , 2.52227182, 2.93835639]]), 'iteration': 1}, {'bic': 40.8307541248476, 'k': 2, 'vertices': array([[0.        , 4.33141006, 3.22464998],
#        [0.        , 2.52227182, 2.93835639]]), 'iteration': 2}, {'bic': 40.8307541248476, 'k': 2, 'vertices': array([[0.        , 4.33141006, 3.22464998],
#        [0.        , 2.52227182, 2.93835639]]), 'iteration': 3}, {'bic': 40.8307541248476, 'k': 2, 'vertices': array([[0.        , 4.33141006, 3.22464998],
#        [0.        , 2.52227182, 2.93835639]]), 'iteration': 4}, {'bic': 40.8307541248476, 'k': 2, 'vertices': array([[0.        , 4.33141006, 3.22464998],
#        [0.        , 2.52227182, 2.93835639]]), 'iteration': 5}, {'bic': 20.72632187444461, 'k': 3, 'vertices': array([[ 0.        ,  2.29999995, -0.25099864],
#        [ 0.        ,  2.54454365,  2.8890156 ],
#        [ 0.        ,  4.43141008,  4.84399789]]), 'iteration': 1}, {'bic': 10.010951822295409, 'k': 3, 'vertices': array([[ 0.        ,  2.29999995, -0.25099864],
#        [ 0.        ,  2.52227182,  2.93835639],
#        [ 0.        ,  6.36282016,  6.7002986 ]]), 'iteration': 2}, {'bic': 10.010951822295409, 'k': 3, 'vertices': array([[ 0.        ,  2.29999995, -0.25099864],
#        [ 0.        ,  2.52227182,  2.93835639],
#        [ 0.        ,  6.36282016,  6.7002986 ]]), 'iteration': 3}, {'bic': 10.010951822295409, 'k': 3, 'vertices': array([[ 0.        ,  2.29999995, -0.25099864],
#        [ 0.        ,  2.52227182,  2.93835639],
#        [ 0.        ,  6.36282016,  6.7002986 ]]), 'iteration': 4}, {'bic': 10.010951822295409, 'k': 3, 'vertices': array([[ 0.        ,  2.29999995, -0.25099864],
#        [ 0.        ,  2.52227182,  2.93835639],
#        [ 0.        ,  6.36282016,  6.7002986 ]]), 'iteration': 5}]}, 'both': {'BIC': 10.010951822295437, 'k': 3, 'centroids': array([[-3.54788068,  2.29999995, -0.25099864],
#        [-3.90000008,  2.52227182,  2.93835639],
#        [-3.70000004,  6.36282016,  6.7002986 ]]), 'iteration': 1, 'all_iterations': [{'bic': 46.96557032004647, 'k': 1, 'vertices': array([[-3.76197022,  3.42684094,  3.08150319]]), 'iteration': 1}, {'bic': 46.96557032004647, 'k': 1, 'vertices': array([[-3.76197022,  3.42684094,  3.08150319]]), 'iteration': 2}, {'bic': 46.96557032004647, 'k': 1, 'vertices': array([[-3.76197022,  3.42684094,  3.08150319]]), 'iteration': 3}, {'bic': 46.96557032004647, 'k': 1, 'vertices': array([[-3.76197022,  3.42684094,  3.08150319]]), 'iteration': 4}, {'bic': 46.96557032004647, 'k': 1, 'vertices': array([[-3.76197022,  3.42684094,  3.08150319]]), 'iteration': 5}, {'bic': 40.83650166676931, 'k': 2, 'vertices': array([[-3.90000008,  2.52227182,  2.93835639],
#        [-3.62394036,  4.33141006,  3.22464998]]), 'iteration': 1}, {'bic': 40.83650166676931, 'k': 2, 'vertices': array([[-3.90000008,  2.52227182,  2.93835639],
#        [-3.62394036,  4.33141006,  3.22464998]]), 'iteration': 2}, {'bic': 40.83650166676931, 'k': 2, 'vertices': array([[-3.90000008,  2.52227182,  2.93835639],
#        [-3.62394036,  4.33141006,  3.22464998]]), 'iteration': 3}, {'bic': 40.83650166676931, 'k': 2, 'vertices': array([[-3.90000008,  2.52227182,  2.93835639],
#        [-3.62394036,  4.33141006,  3.22464998]]), 'iteration': 4}, {'bic': 40.83650166676931, 'k': 2, 'vertices': array([[-3.90000008,  2.52227182,  2.93835639],
#        [-3.62394036,  4.33141006,  3.22464998]]), 'iteration': 5}, {'bic': 10.010951822295437, 'k': 3, 'vertices': array([[-3.54788068,  2.29999995, -0.25099864],
#        [-3.90000008,  2.52227182,  2.93835639],
#        [-3.70000004,  6.36282016,  6.7002986 ]]), 'iteration': 1}, {'bic': 10.010951822295437, 'k': 3, 'vertices': array([[-3.54788068,  2.29999995, -0.25099864],
#        [-3.90000008,  2.52227182,  2.93835639],
#        [-3.70000004,  6.36282016,  6.7002986 ]]), 'iteration': 2}, {'bic': 10.010951822295437, 'k': 3, 'vertices': array([[-3.54788068,  2.29999995, -0.25099864],
#        [-3.90000008,  2.52227182,  2.93835639],
#        [-3.70000004,  6.36282016,  6.7002986 ]]), 'iteration': 3}, {'bic': 10.010951822295437, 'k': 3, 'vertices': array([[-3.54788068,  2.29999995, -0.25099864],
#        [-3.90000008,  2.52227182,  2.93835639],
#        [-3.70000004,  6.36282016,  6.7002986 ]]), 'iteration': 4}, {'bic': 10.010951822295437, 'k': 3, 'vertices': array([[-3.54788068,  2.29999995, -0.25099864],
#        [-3.90000008,  2.52227182,  2.93835639],
#        [-3.70000004,  6.36282016,  6.7002986 ]]), 'iteration': 5}]}}}}

# %% [markdown]
# ## Create Patterns from Vertices

# %%
# Choose a pattern forming algorithm, I'm using this default one, but you can write your own child class of PatternFormer
from algorithms.pattern.default_pattern_former import DefaultPatternFormer
event_patterns.pattern_former = DefaultPatternFormer()
event_patterns.form_patterns()

# Print patterns and the unique tracklets within each pattern along with vertex information
patterns = event_patterns.get_patterns()
for pattern in patterns:
    print(f"\nPattern with {len(pattern.get_vertices())} vertices.")

    # Print info for each vertex in the pattern
    for vertex in pattern.get_vertices():
        tracklet_ids = [t.tracklet_id for t in vertex.get_tracklets()]
        print(f"  Vertex {vertex.vertex_id} (tracklet_ids={tracklet_ids})")

    print("  Unique Tracklets:")
    unique_tracklets = pattern.get_unique_tracklets()
    for tracklet in unique_tracklets:
        print(f"    {tracklet}")


# See the extra info stored at this point
print()
print("Extra event info:")
print(event_patterns.extra_info)
# Out:
# Pattern with 3 vertices.
#   Vertex 0 (tracklet_ids=[0])
#   Vertex 2 (tracklet_ids=[1, 0])
#   Vertex 1 (tracklet_ids=[1])
#   Unique Tracklets:
#     Tracklet(id=1, particle_id=-11, name=e^{+}, color=#D62728, e_id=501, hits=34, extra_info_keys=None, endpoints=(Point3D(x=-3.9000000955066736, y=2.544543645250344, z=2.8890156019267415), Point3D(x=-3.7000000396190598, y=6.362820158978518, z=6.700298599357359)))
#     Tracklet(id=0, particle_id=211, name=\pi^{+}, color=#2CA02C, e_id=501, hits=23, extra_info_keys=None, endpoints=(Point3D(x=-3.5478806753736434, y=2.2999999522858343, z=-0.2509986437801748), Point3D(x=-3.900000056326043, y=2.500000000000054, z=2.987697185521827)))
#
# Extra event info:
# {'stage': <Stage.PATTERNS_FORMED: 3>, 'tracklet_algorithm_info': {'n_patterns_truth': 1, 'particles_in_event_truth': Counter({211: 1, -11: 1}), 'patterns_truth': {0: [0, 1]}, 'particles_in_event_reco': Counter({211: 1, -11: 1})}, 'vertex_algorithm_info': {'vertex_comparison': {'front_vertices': {Vertex(id=0, num_tracklets=1), Vertex(id=2, num_tracklets=2), Vertex(id=1, num_tracklets=1)}, 'back_vertices': {Vertex(id=0, num_tracklets=1), Vertex(id=1, num_tracklets=2), Vertex(id=2, num_tracklets=1)}, 'both_vertices': {Vertex(id=0, num_tracklets=1), Vertex(id=1, num_tracklets=2), Vertex(id=2, num_tracklets=1)}}, 'stats': {'front': {'BIC': 9.972601881213503, 'k': 3, 'centroids': array([[-3.54788068,  0.        , -0.25099864],
#        [-3.70000004,  0.        ,  6.7002986 ],
#        [-3.90000008,  0.        ,  2.93835639]]), 'iteration': 1, 'all_iterations': [{'bic': 36.25508050101685, 'k': 1, 'vertices': array([[-3.76197022,  0.        ,  3.08150319]]), 'iteration': 1}, {'bic': 36.25508050101685, 'k': 1, 'vertices': array([[-3.76197022,  0.        ,  3.08150319]]), 'iteration': 2}, {'bic': 36.25508050101685, 'k': 1, 'vertices': array([[-3.76197022,  0.        ,  3.08150319]]), 'iteration': 3}, {'bic': 36.25508050101685, 'k': 1, 'vertices': array([[-3.76197022,  0.        ,  3.08150319]]), 'iteration': 4}, {'bic': 36.25508050101685, 'k': 1, 'vertices': array([[-3.76197022,  0.        ,  3.08150319]]), 'iteration': 5}, {'bic': 35.70230266722402, 'k': 2, 'vertices': array([[-3.72394039,  0.        ,  1.31900848],
#        [-3.80000005,  0.        ,  4.84399789]]), 'iteration': 1}, {'bic': 35.70230266722402, 'k': 2, 'vertices': array([[-3.72394039,  0.        ,  1.31900848],
#        [-3.80000005,  0.        ,  4.84399789]]), 'iteration': 2}, {'bic': 35.70230266722402, 'k': 2, 'vertices': array([[-3.72394039,  0.        ,  1.31900848],
#        [-3.80000005,  0.        ,  4.84399789]]), 'iteration': 3}, {'bic': 35.70230266722402, 'k': 2, 'vertices': array([[-3.72394039,  0.        ,  1.31900848],
#        [-3.80000005,  0.        ,  4.84399789]]), 'iteration': 4}, {'bic': 35.70230266722402, 'k': 2, 'vertices': array([[-3.72394039,  0.        ,  1.31900848],
#        [-3.80000005,  0.        ,  4.84399789]]), 'iteration': 5}, {'bic': 9.972601881213503, 'k': 3, 'vertices': array([[-3.54788068,  0.        , -0.25099864],
#        [-3.70000004,  0.        ,  6.7002986 ],
#        [-3.90000008,  0.        ,  2.93835639]]), 'iteration': 1}, {'bic': 9.972601881213503, 'k': 3, 'vertices': array([[-3.54788068,  0.        , -0.25099864],
#        [-3.70000004,  0.        ,  6.7002986 ],
#        [-3.90000008,  0.        ,  2.93835639]]), 'iteration': 2}, {'bic': 9.972601881213503, 'k': 3, 'vertices': array([[-3.54788068,  0.        , -0.25099864],
#        [-3.70000004,  0.        ,  6.7002986 ],
#        [-3.90000008,  0.        ,  2.93835639]]), 'iteration': 3}, {'bic': 9.972601881213503, 'k': 3, 'vertices': array([[-3.54788068,  0.        , -0.25099864],
#        [-3.70000004,  0.        ,  6.7002986 ],
#        [-3.90000008,  0.        ,  2.93835639]]), 'iteration': 4}, {'bic': 9.972601881213503, 'k': 3, 'vertices': array([[-3.54788068,  0.        , -0.25099864],
#        [-3.70000004,  0.        ,  6.7002986 ],
#        [-3.90000008,  0.        ,  2.93835639]]), 'iteration': 5}]}, 'back': {'BIC': 10.010951822295409, 'k': 3, 'centroids': array([[ 0.        ,  2.29999995, -0.25099864],
#        [ 0.        ,  2.52227182,  2.93835639],
#        [ 0.        ,  6.36282016,  6.7002986 ]]), 'iteration': 2, 'all_iterations': [{'bic': 46.85525532440403, 'k': 1, 'vertices': array([[0.        , 3.42684094, 3.08150319]]), 'iteration': 1}, {'bic': 46.85525532440403, 'k': 1, 'vertices': array([[0.        , 3.42684094, 3.08150319]]), 'iteration': 2}, {'bic': 46.85525532440403, 'k': 1, 'vertices': array([[0.        , 3.42684094, 3.08150319]]), 'iteration': 3}, {'bic': 46.85525532440403, 'k': 1, 'vertices': array([[0.        , 3.42684094, 3.08150319]]), 'iteration': 4}, {'bic': 46.85525532440403, 'k': 1, 'vertices': array([[0.        , 3.42684094, 3.08150319]]), 'iteration': 5}, {'bic': 40.8307541248476, 'k': 2, 'vertices': array([[0.        , 4.33141006, 3.22464998],
#        [0.        , 2.52227182, 2.93835639]]), 'iteration': 1}, {'bic': 40.8307541248476, 'k': 2, 'vertices': array([[0.        , 4.33141006, 3.22464998],
#        [0.        , 2.52227182, 2.93835639]]), 'iteration': 2}, {'bic': 40.8307541248476, 'k': 2, 'vertices': array([[0.        , 4.33141006, 3.22464998],
#        [0.        , 2.52227182, 2.93835639]]), 'iteration': 3}, {'bic': 40.8307541248476, 'k': 2, 'vertices': array([[0.        , 4.33141006, 3.22464998],
#        [0.        , 2.52227182, 2.93835639]]), 'iteration': 4}, {'bic': 40.8307541248476, 'k': 2, 'vertices': array([[0.        , 4.33141006, 3.22464998],
#        [0.        , 2.52227182, 2.93835639]]), 'iteration': 5}, {'bic': 20.72632187444461, 'k': 3, 'vertices': array([[ 0.        ,  2.29999995, -0.25099864],
#        [ 0.        ,  2.54454365,  2.8890156 ],
#        [ 0.        ,  4.43141008,  4.84399789]]), 'iteration': 1}, {'bic': 10.010951822295409, 'k': 3, 'vertices': array([[ 0.        ,  2.29999995, -0.25099864],
#        [ 0.        ,  2.52227182,  2.93835639],
#        [ 0.        ,  6.36282016,  6.7002986 ]]), 'iteration': 2}, {'bic': 10.010951822295409, 'k': 3, 'vertices': array([[ 0.        ,  2.29999995, -0.25099864],
#        [ 0.        ,  2.52227182,  2.93835639],
#        [ 0.        ,  6.36282016,  6.7002986 ]]), 'iteration': 3}, {'bic': 10.010951822295409, 'k': 3, 'vertices': array([[ 0.        ,  2.29999995, -0.25099864],
#        [ 0.        ,  2.52227182,  2.93835639],
#        [ 0.        ,  6.36282016,  6.7002986 ]]), 'iteration': 4}, {'bic': 10.010951822295409, 'k': 3, 'vertices': array([[ 0.        ,  2.29999995, -0.25099864],
#        [ 0.        ,  2.52227182,  2.93835639],
#        [ 0.        ,  6.36282016,  6.7002986 ]]), 'iteration': 5}]}, 'both': {'BIC': 10.010951822295437, 'k': 3, 'centroids': array([[-3.54788068,  2.29999995, -0.25099864],
#        [-3.90000008,  2.52227182,  2.93835639],
#        [-3.70000004,  6.36282016,  6.7002986 ]]), 'iteration': 1, 'all_iterations': [{'bic': 46.96557032004647, 'k': 1, 'vertices': array([[-3.76197022,  3.42684094,  3.08150319]]), 'iteration': 1}, {'bic': 46.96557032004647, 'k': 1, 'vertices': array([[-3.76197022,  3.42684094,  3.08150319]]), 'iteration': 2}, {'bic': 46.96557032004647, 'k': 1, 'vertices': array([[-3.76197022,  3.42684094,  3.08150319]]), 'iteration': 3}, {'bic': 46.96557032004647, 'k': 1, 'vertices': array([[-3.76197022,  3.42684094,  3.08150319]]), 'iteration': 4}, {'bic': 46.96557032004647, 'k': 1, 'vertices': array([[-3.76197022,  3.42684094,  3.08150319]]), 'iteration': 5}, {'bic': 40.83650166676931, 'k': 2, 'vertices': array([[-3.90000008,  2.52227182,  2.93835639],
#        [-3.62394036,  4.33141006,  3.22464998]]), 'iteration': 1}, {'bic': 40.83650166676931, 'k': 2, 'vertices': array([[-3.90000008,  2.52227182,  2.93835639],
#        [-3.62394036,  4.33141006,  3.22464998]]), 'iteration': 2}, {'bic': 40.83650166676931, 'k': 2, 'vertices': array([[-3.90000008,  2.52227182,  2.93835639],
#        [-3.62394036,  4.33141006,  3.22464998]]), 'iteration': 3}, {'bic': 40.83650166676931, 'k': 2, 'vertices': array([[-3.90000008,  2.52227182,  2.93835639],
#        [-3.62394036,  4.33141006,  3.22464998]]), 'iteration': 4}, {'bic': 40.83650166676931, 'k': 2, 'vertices': array([[-3.90000008,  2.52227182,  2.93835639],
#        [-3.62394036,  4.33141006,  3.22464998]]), 'iteration': 5}, {'bic': 10.010951822295437, 'k': 3, 'vertices': array([[-3.54788068,  2.29999995, -0.25099864],
#        [-3.90000008,  2.52227182,  2.93835639],
#        [-3.70000004,  6.36282016,  6.7002986 ]]), 'iteration': 1}, {'bic': 10.010951822295437, 'k': 3, 'vertices': array([[-3.54788068,  2.29999995, -0.25099864],
#        [-3.90000008,  2.52227182,  2.93835639],
#        [-3.70000004,  6.36282016,  6.7002986 ]]), 'iteration': 2}, {'bic': 10.010951822295437, 'k': 3, 'vertices': array([[-3.54788068,  2.29999995, -0.25099864],
#        [-3.90000008,  2.52227182,  2.93835639],
#        [-3.70000004,  6.36282016,  6.7002986 ]]), 'iteration': 3}, {'bic': 10.010951822295437, 'k': 3, 'vertices': array([[-3.54788068,  2.29999995, -0.25099864],
#        [-3.90000008,  2.52227182,  2.93835639],
#        [-3.70000004,  6.36282016,  6.7002986 ]]), 'iteration': 4}, {'bic': 10.010951822295437, 'k': 3, 'vertices': array([[-3.54788068,  2.29999995, -0.25099864],
#        [-3.90000008,  2.52227182,  2.93835639],
#        [-3.70000004,  6.36282016,  6.7002986 ]]), 'iteration': 5}]}}}, 'pattern_algorithm_info': {}}

# %% [markdown]
# ## (Optional) Validate Event Against Truth
# This requires some truth information to be stored in the pattern's "extra_info". In this case, we stored it in the tracklet forming stage

# %%
# Choose a validation algorithm, I'm using one that checks that each pattern in the reco and truth contain the same tracklet ids
# but you can write your own child class of EventValidator
from deprecated.algorithms.validation.tracklet_grouping_validator import TrackletGroupingValidator
event_patterns.validator = TrackletGroupingValidator(verbose = 1)
event_patterns.validate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 5
#       3 from algorithms.validation.tracklet_grouping_validator import TrackletGroupingValidator
#       4 event_patterns.validator = TrackletGroupingValidator(verbose = 1)
# ----> 5 event_patterns.validate()
#
# File ~/large_projects/simulation/workspace/playground/reco_algorithm_tests/deprecated/models/event_patterns.py:111, in EventPatterns.validate(self)
#     108     return True
#     110 # Perform validation
# --> 111 is_valid = self.validator.validate(self)
#     113 # Update the stage to VALIDATION_RAN
#     114 self.extra_info["stage"] = Stage.VALIDATION_RAN
#
# File ~/large_projects/simulation/workspace/playground/reco_algorithm_tests/algorithms/validation/tracklet_grouping_validator.py:16, in TrackletGroupingValidator.validate(self, event)
#       9 def validate(self, event: Event) -> bool:
#      10     """
#      11     Validates that the tracklet IDs in each reconstructed pattern match the ones
#      12     stored in the truth-level `patterns_truth` from the algorithm_info.
#      13
#      14     Returns True if valid, False otherwise.
#      15     """
# ---> 16     if "tracklet_algorithm_info" not in event.get_extra_info():
#      17         raise ValueError("No tracklet algorithm info found in EventPatterns.")
#      19     patterns_truth = event.extra_info["tracklet_algorithm_info"].get("patterns_truth")
#
# AttributeError: 'EventPatterns' object has no attribute 'get_extra_info'

# %% [markdown]
# # Reconstruct Multiple Events

# %% [markdown]
# ## Make cuts on the data set

# %%
# Number of events to process (set to None or a large number to process all events)
MAX_EVENTS = None
N_EVENTS = tree.GetEntries() if MAX_EVENTS is None else min(MAX_EVENTS, tree_pf.GetEntries())

use_pitar = True
use_in_fid_vol = True

nentries = tree.GetEntries()
all_events = []  # Store event IDs of all events that pass the initial cuts

for iEntry in tqdm(range(min(nentries, N_EVENTS)), desc="Processing Events"):

    patternFailed = False
    tree.GetEntry(iEntry)

    # SELECTIONS
    pitar = any(info.Has(r.kPitar) for info in tree.infoVec)

    if (not pitar) and use_pitar:
        continue

    in_fid_vol = True
    for tracklet in tree.trackletVec:
        for hit in tracklet.GetAllHits():
            vname = geoHelper.GetVolumeName(hit.GetVID()).Data()
            if 'atar' in vname:
                side = vname[11]
                if (side == "f" and abs(geoHelper.GetX(hit.GetVID())) > 8) or \
                   (side == "b" and abs(geoHelper.GetY(hit.GetVID())) > 8):
                    in_fid_vol = False

    if (not in_fid_vol) and use_in_fid_vol:
        continue

    all_events.append(iEntry)

# %% [markdown]
# ## Run Reconstruction on Events

# %% [markdown]
# ### (Optional) Reload algorithms

# %%
import importlib

# Reload tracklet formers
import algorithms.tracklet.reconstructed_tracklet_former
importlib.reload(algorithms.tracklet.reconstructed_tracklet_former)

import algorithms.tracklet.default_tracklet_former
importlib.reload(algorithms.tracklet.default_tracklet_former)

# Reload vertex formers
import algorithms.vertex.kmeans_vertex_former
importlib.reload(algorithms.vertex.kmeans_vertex_former)

import algorithms.vertex.kmeans_vertex_former_given_endpoints
importlib.reload(algorithms.vertex.kmeans_vertex_former_given_endpoints)

# %%
from algorithms.tracklet.reconstructed_tracklet_former import ReconstructedTrackletFormer
from algorithms.tracklet.default_tracklet_former import DefaultTrackletFormer

from algorithms.vertex.kmeans_vertex_former_given_endpoints import KMeansVertexFormerGivenEndpoints
from algorithms.vertex.kmeans_vertex_former import KMeansVertexFormer

from algorithms.pattern.default_pattern_former import DefaultPatternFormer

from deprecated.algorithms.validation.tracklet_grouping_validator import TrackletGroupingValidator

# Preallocate array
reconstructed_events = np.empty(len(all_events), dtype=object)

# tqdm with simple progress description
with tqdm(total=len(all_events), desc="Reconstructing events") as pbar:
    for i, event_index in enumerate(all_events):
        event_patterns = EventPatterns(event_index, 
                                       #DefaultTrackletFormer(truth_tree),
                                       ReconstructedTrackletFormer(truth_tree), 
                                       KMeansVertexFormerGivenEndpoints(sigma=1.5, n_iters=4, plane="both", planes_to_run={}, seed_method="random"), # Only run clustering using (x,z) info, speeds things up slightly 
                                       DefaultPatternFormer(), 
                                       TrackletGroupingValidator())
        event_patterns.form_all(tree, geoHelper, event_index)
        reconstructed_events[i] = event_patterns
        pbar.update(1)

# %% [markdown]
# # Check/View Algorithm Performance

# %% [markdown]
# ## Performance vs. Particle composition

# %% [markdown]
# ### Performance categorized by reconstructed particle componsition
# Sometimes tracklets exist in truth, but do not create a hit in the atar. As a result, we cannot always construct the true particle composition.

# %%
reload(plotting_utils)
title = f"Pattern Reconstruction by Reconstructed Particle Composition ($N_{{\\text{{events}}}} = {len(reconstructed_events)}$)"
plotting_utils.plot_event_classification_from_patterns(reconstructed_events, use_truth_particles = False, title =  title)

# %% [markdown]
# ### Performance categorized by true particle componsition
# We can tag each event with the true particle composition information and plot against that instead to also see performance based on true particle composition

# %%
reload(plotting_utils)
title = f"Pattern Reconstruction by True Particle Composition ($N_{{\\text{{events}}}} = {len(reconstructed_events)}$)"
plotting_utils.plot_event_classification_from_patterns(reconstructed_events, use_truth_particles = True, title =  title)

# %% [markdown]
# ## Performance vs. True Number of Patterns

# %%
reload(plotting_utils)
title = f"Pattern Reconstruction by True Particle Composition ($N_{{\\text{{events}}}} = {len(reconstructed_events)}$)"
plotting_utils.plot_event_patterns_summary(reconstructed_events, title =  None)
